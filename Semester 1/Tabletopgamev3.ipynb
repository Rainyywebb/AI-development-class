# %% [markdown]
# # Question: given that there are 40 land cards in the "Endless Punishment" MTG deck, what is the probability that I will pull a basic land AND a legendary land on my first hand. MTG commander decks contain 7 cards and the 40 land cards consists of dual, basic, and legendary land.
#
# What constitutes one trial of the situation: one trial would be the player (assuming that the deck has been shuffled and no other cards have been dealt) Drawing your first hand would be one trial.
#
# What outcome are you measuring: what is the probability of drawing a specific card from the deck. (in this case, I'm searching for the probability of drawing a basic land on my first hand)
#
#
# answer:

# %%
import random
import pandas as pd
import seaborn as sns 

df = pd.read_csv('EndlessPunishmentdeck.csv')

# Repeat 10 times
for i in range(10):
    print(f"\nHand {i+1}:")
    Drawn_hand = df.sample(n=7)   # Draw 7 random rows
    print(Drawn_hand)
# Out:
# Hand 1:
#     Unnamed: 0                          Card    Card Type
# 66         NaN                Evolving Winds         Land
# 34        35.0       Bastion of Rememberance  Enchantment
# 48         NaN                Feed the Swarm       Spells
# 35        36.0            Theater of Horrors  Enchantment
# 19        20.0            Nighshade Havester     Creature
# 0          1.0  Valgavoth, Harrower of souls     Creature
# 1          2.0             Kederekt Parasite     Creature
#
# Hand 2:
#     Unnamed: 0                      Card   Card Type
# 6          7.0  Braids, Arisen Nightmare    Creature
# 72         NaN                  Mountain  Basic Land
# 81         NaN                     Swamp  Basic Land
# 69         NaN           Spinerock Knoll        Land
# 58         NaN       Sadistic Shell Game      Spells
# 86         NaN        Blackleaves Cliffs   Dual Land
# 73         NaN                  Mountain  Basic Land
#
# Hand 3:
# ...
